# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
from sklearn import preprocessing
# %matplotlib inline

# %%
dname = 'simulator/sample_data/'
filepath = os.path.join(dname, 'driving_log.csv')
dataset = pd.read_csv(filepath)

# %%
dataset.head()
# Out:
#                                    center  \
# 0  IMG/center_2016_12_01_13_30_48_287.jpg
# 1  IMG/center_2016_12_01_13_30_48_404.jpg
# 2  IMG/center_2016_12_01_13_31_12_937.jpg
# 3  IMG/center_2016_12_01_13_31_13_037.jpg
# 4  IMG/center_2016_12_01_13_31_13_177.jpg
#
#                                     left  \
# 0   IMG/left_2016_12_01_13_30_48_287.jpg
# 1   IMG/left_2016_12_01_13_30_48_404.jpg
# 2   IMG/left_2016_12_01_13_31_12_937.jpg
# 3   IMG/left_2016_12_01_13_31_13_037.jpg
# 4   IMG/left_2016_12_01_13_31_13_177.jpg
#
#                                     right  steering  throttle  brake  \
# 0   IMG/right_2016_12_01_13_30_48_287.jpg       0.0       0.0    0.0
# 1   IMG/right_2016_12_01_13_30_48_404.jpg       0.0       0.0    0.0
# 2   IMG/right_2016_12_01_13_31_12_937.jpg       0.0       0.0    0.0
# 3   IMG/right_2016_12_01_13_31_13_037.jpg       0.0       0.0    0.0
# 4   IMG/right_2016_12_01_13_31_13_177.jpg       0.0       0.0    0.0
#
#        speed
# 0  22.148290
# 1  21.879630
# 2   1.453011
# 3   1.438419
# 4   1.418236

# %%
dataset.columns
# Out:
# Index(['center', 'left', 'right', 'steering', 'throttle', 'brake', 'speed'], dtype='object')

# %%
dataset_device = dataset.iloc[:,3:]

# %%
dataset_device.describe()
# Out:
#           steering     throttle        brake        speed
# count  8036.000000  8036.000000  8036.000000  8036.000000
# mean      0.004070     0.869660     0.001970    28.169839
# std       0.128840     0.301326     0.036565     6.149327
# min      -0.942695     0.000000     0.000000     0.502490
# 25%       0.000000     0.985533     0.000000    30.183093
# 50%       0.000000     0.985533     0.000000    30.186400
# 75%       0.000000     0.985533     0.000000    30.186640
# max       1.000000     0.985533     1.000000    30.709360

# %%
dataset_device.plot()

# %%
dataset_device.plot(secondary_y=['speed'], alpha=0.8)

# %%
dataset_device.plot(secondary_y=['speed'], alpha=0.8, xlim=(3000, 5000))

# %%
dataset_device.plot(secondary_y=['speed'], alpha=0.8, xlim=(0, 3000))

# %%
dataset_device.plot(secondary_y=['speed'], alpha=0.8, xlim=(0, 500))

# %%
dname = 'simulator/csvs/'
filepath = os.path.join(dname, 'driving_log_v1.csv')
dataset = pd.read_csv(filepath, header=None)
dataset.columns = ['center', 'left', 'right', 'steering', 'throttle', 'brake', 'speed']

# %%
dataset_device = dataset.iloc[:,3:]

# %%
dataset_device.describe()
# Out:
#           steering     throttle   brake        speed
# count  2594.000000  2594.000000  2594.0  2594.000000
# mean     -0.011344     0.954527     0.0    28.137962
# std       0.251110     0.204049     0.0     7.036263
# min      -1.000000     0.000000     0.0     0.000077
# 25%       0.000000     1.000000     0.0    30.184683
# 50%       0.000000     1.000000     0.0    30.190130
# 75%       0.000000     1.000000     0.0    30.190300
# max       1.000000     1.000000     0.0    30.434010

# %%
dataset_device.plot(secondary_y=['speed'], alpha=0.8)

# %%
dataset_device.plot(secondary_y=['speed'], alpha=0.8, xlim=(0, 500))

# %%
dname = 'simulator/csvs/'
filepath = os.path.join(dname, 'driving_log_v2.csv')
dataset = pd.read_csv(filepath, header=None)
dataset.columns = ['center', 'left', 'right', 'steering', 'throttle', 'brake', 'speed']

# %%
dataset_device = dataset.iloc[:,3:]

# %%
dataset_device.describe()
# Out:
#           steering     throttle   brake        speed
# count  7493.000000  7493.000000  7493.0  7493.000000
# mean     -0.032348     0.982905     0.0    29.674038
# std       0.189680     0.127806     0.0     3.421763
# min      -1.000000     0.000000     0.0     0.000345
# 25%       0.000000     1.000000     0.0    30.188530
# 50%       0.000000     1.000000     0.0    30.190090
# 75%       0.000000     1.000000     0.0    30.190300
# max       1.000000     1.000000     0.0    30.520350

# %%
dataset_device.plot(secondary_y=['speed'], alpha=0.8)

# %%
dataset_device.plot(secondary_y=['speed'], alpha=0.8, xlim=(0, 500))

# %%
dataset_device.plot(secondary_y=['speed'], alpha=0.8, xlim=(0, 500))

# %% [markdown]
# ### Image flip example

# %%
filepath = "examples/center_2017_01_30_23_21_22_330.jpg"
img = plt.imread(filepath)

# %%
img.shape
# Out:
# (160, 320, 3)

# %%
plt.imshow(img)

# %%
from keras.preprocessing.image import flip_axis
from model import random_flip_img, random_h_shift_img
# Out:
# Using TensorFlow backend.

# %%
crop_img = img[70:-25]

# %%
flip_img, angle = random_flip_img(img, 0.4)
angle
# Out:
# -0.4

# %%
h_shift_img, angle = random_h_shift_img(img, 0.4)
angle
# Out:
# 0.22000000000000003

# %%
plt.imshow(flip_img)

# %%
fig = plt.figure(frameon=False)
ax = plt.Axes(fig, [0., 0., 1., 1.])
ax.set_axis_off()
fig.add_axes(ax)
ax.imshow(img)
fig.savefig('examples/center_2017_01_30_23_21_22_330_org.jpg', 
            bbox_inches='tight', pad_inches=0)

# %%
fig = plt.figure(frameon=False)
ax = plt.Axes(fig, [0., 0., 1., 1.])
ax.set_axis_off()
fig.add_axes(ax)
ax.imshow(flip_img)
fig.savefig('examples/center_2017_01_30_23_21_22_330_flip.jpg', 
            bbox_inches='tight', pad_inches=0)

# %%
fig = plt.figure(frameon=False)
ax = plt.Axes(fig, [0., 0., 1., 1.])
ax.set_axis_off()
fig.add_axes(ax)
ax.imshow(h_shift_img)
fig.savefig('examples/center_2017_01_30_23_21_22_330_shifted.jpg', 
            bbox_inches='tight', pad_inches=0)

# %%
fig = plt.figure(frameon=False)
ax = plt.Axes(fig, [0., 0., 1., 1.])
ax.set_axis_off()
fig.add_axes(ax)
ax.imshow(crop_img)
fig.savefig('examples/center_2017_01_30_23_21_22_330_crop.jpg', 
            bbox_inches='tight', pad_inches=0)

# %%
plt.imshow(crop_img)
